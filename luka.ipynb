# %% [markdown]
# # Installations and imports

# %%
## when you pull this file from the repo make sure to pip install the following: pip install pandas, pip install ipykernel pip install matplotlib, pip install seaborn

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # 1. Luka's NBA data

# %%
luka_data_nba = pd.read_csv('data/luka_data.csv')
luka_data_nba.head()
# Out:
#     Season  Age Team   Lg Pos   G  GS    MP    FG   FGA  ...  ORB  DRB  TRB  \
# 0  2018-19   19  DAL  NBA  SG  72  72  32.2   7.0  16.5  ...  1.2  6.6  7.8
# 1  2019-20   20  DAL  NBA  PG  61  61  33.6   9.5  20.6  ...  1.3  8.1  9.4
# 2  2020-21   21  DAL  NBA  PG  66  66  34.3   9.8  20.5  ...  0.8  7.2  8.0
# 3  2021-22   22  DAL  NBA  PG  65  65  35.4   9.9  21.6  ...  0.9  8.3  9.1
# 4  2022-23   23  DAL  NBA  PG  66  66  36.2  10.9  22.0  ...  0.8  7.8  8.6
#
#    AST  STL  BLK  TOV   PF   PTS             Awards
# 0  6.0  1.1  0.3  3.4  1.9  21.2              ROY-1
# 1  8.8  1.0  0.2  4.3  2.5  28.8        MVP-4ASNBA1
# 2  8.6  1.0  0.5  4.3  2.3  27.7        MVP-6ASNBA1
# 3  8.7  1.2  0.6  4.5  2.2  28.4        MVP-5ASNBA1
# 4  8.0  1.4  0.5  3.6  2.5  32.4  MVP-8CPOY-8ASNBA1
#
# [5 rows x 31 columns]

# %% [markdown]
# # 2. Luka's Euroleague data

# %%
luka_data_euro = pd.read_csv('data/euroleague_stats.csv')
luka_data_euro.head()
# Out:
#     Season         Club      League   G    MP   FG   FG%     3P  3PA  3P%  \
# 0  2015-16  Real Madrid  EuroLeague  12  11.1  0.9   2.3  0.407  0.4  1.3
# 1  2016-17  Real Madrid  EuroLeague  35  19.9  2.4   5.6  0.434  1.1  3.0
# 2  2017-18  Real Madrid  EuroLeague  33  25.9  4.7  10.5  0.451  1.7  5.2
#
#    ...    FT.  ORB  DRB  TRB  AST  STL  BLK  TOV   PF   PTS
# 0  ...  0.882  0.3  2.1  2.3  2.0  0.2  0.3  1.2  0.6   3.5
# 1  ...  0.844  0.9  3.5  4.5  4.2  0.9  0.2  1.8  1.3   7.8
# 2  ...  0.816  0.8  4.0  4.8  4.3  1.1  0.3  2.3  1.5  16.0
#
# [3 rows x 26 columns]

# %% [markdown]
# # 3. Luka's LIGA ACB data

# %%
luka_data_liga = pd.read_csv('data/liga_acb_stats.csv')
luka_data_liga.head()
# Out:
#     Season         Club    League Country Regular Season/Playoffs   G    MP  \
# 0  2014-15  Real Madrid  Liga ACB   Spain          Regular Season   3   2.7
# 1  2015-16  Real Madrid  Liga ACB   Spain          Regular Season  31  14.2
# 2  2016-17  Real Madrid  Liga ACB   Spain          Regular Season  32  19.9
# 3  2017-18  Real Madrid  Liga ACB   Spain          Regular Season  28  24.0
# 4  2014-15  Real Madrid  Liga ACB   Spain                Playoffs   2   8.0
#
#     FG  FGA    FG%  ...    FT%  ORB  DRB  TRB  AST  STL  BLK  TOV   PF   PTS
# 0  0.3  1.0  0.333  ...  0.750  0.3  0.3  0.7  0.0  0.0  0.0  0.0  0.3   2.0
# 1  1.6  3.1  0.526  ...  0.721  0.6  2.2  2.8  2.0  0.4  0.3  1.5  1.9   4.9
# 2  2.7  5.8  0.460  ...  0.787  1.0  3.3  4.3  3.1  0.7  0.4  2.0  1.3   7.8
# 3  4.3  9.3  0.463  ...  0.773  1.0  4.7  5.7  5.0  1.1  0.4  2.1  1.6  12.8
# 4  0.5  1.5  0.333  ...    NaN  0.0  2.0  2.0  0.0  0.0  0.0  0.5  0.0   1.0
#
# [5 rows x 28 columns]

# %% [markdown]
# # 4. AD's NBA data

# %%
AD_data = pd.read_csv('data/AD.csv')
AD_data.head(15)
# Out:
#      Season     Age    Team      Lg  Pos    G   GS     MP   PER    TS%  ...  \
# 0   2012-13      19     NOH     NBA   PF   64   60   1846  21.7  0.559  ...
# 1   2013-14      20     NOP     NBA   PF   67   66   2358  26.5  0.582  ...
# 2   2014-15      21     NOP     NBA   PF   68   68   2455  30.8  0.591  ...
# 3   2015-16      22     NOP     NBA    C   61   61   2164  25.0  0.559  ...
# 4   2016-17      23     NOP     NBA    C   75   75   2708  27.5  0.580  ...
# 5   2017-18      24     NOP     NBA   PF   75   75   2727  28.9  0.612  ...
# 6   2018-19      25     NOP     NBA    C   56   56   1850  30.3  0.597  ...
# 7   2019-20      26     LAL     NBA   PF   62   62   2131  27.4  0.610  ...
# 8   2020-21      27     LAL     NBA   PF   36   36   1162  22.1  0.556  ...
# 9   2021-22      28     LAL     NBA    C   40   40   1404  23.9  0.578  ...
# 10  2022-23      29     LAL     NBA    C   56   54   1904  27.8  0.627  ...
# 11  2023-24      30     LAL     NBA    C   76   76   2700  25.8  0.621  ...
# 12  2024-25      31     LAL     NBA    C   42   42   1440  27.4  0.601  ...
# 13   13 Yrs  13 Yrs  13 Yrs  13 Yrs  NaN  778  771  26849  26.9  0.593  ...
#
#     USG%   OWS   DWS     WS  WS/48  OBPM  DBPM  BPM  VORP             Awards
# 0   21.8   3.7   2.4    6.1  0.159   1.8   0.7  2.5   2.1              ROY-2
# 1   25.2   7.2   3.2   10.4  0.212   4.0   0.8  4.8   4.0           DPOY-8AS
# 2   27.8   9.9   4.2   14.0  0.274   6.6   2.3  8.9   6.7  MVP-5DPOY-4ASNBA1
# 3   29.6   4.4   2.8    7.2  0.160   3.6   0.4  3.9   3.2           DPOY-9AS
# 4   32.6   5.9   5.1   11.0  0.195   4.4   1.4  5.9   5.4        MVP-9ASNBA1
# 5   30.0   8.8   4.9   13.7  0.241   5.3   1.4  6.7   5.9  MVP-3DPOY-3ASNBA1
# 6   29.5   6.4   3.1    9.5  0.247   7.1   2.3  9.4   5.3                 AS
# 7   29.3   6.7   4.4   11.1  0.250   5.4   2.6  8.0   5.4  MVP-6DPOY-2ASNBA1
# 8   29.2   1.3   2.4    3.7  0.152   2.6   2.2  4.8   2.0                 AS
# 9   27.1   2.6   2.0    4.5  0.155   2.6   1.2  3.8   2.0                NaN
# 10  28.4   5.5   3.4    9.0  0.226   4.6   1.7  6.3   4.0                NaN
# 11  26.7   7.2   4.7   11.8  0.210   3.5   1.7  5.1   4.9       DPOY-4ASNBA2
# 12  30.4   3.8   2.4    6.2  0.208   4.5   1.2  5.8   2.8                NaN
# 13  28.3  73.4  44.9  118.3  0.212   4.4   1.5  5.9  53.8                NaN
#
# [14 rows x 29 columns]
